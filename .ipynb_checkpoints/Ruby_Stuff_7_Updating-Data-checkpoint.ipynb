# %%
cmd = `ls `
# Out:
# "anim20170810-9726-18h3es2-0\nanim20170810-9726-1f74agc-0\nanim20170810-9726-1kgf47n-0\nanim20170810-9726-742ypl-0\nanim20170810-9726-ohxyfv-0\nanim20170810-9726-szfiq7-0\nfit.log\ngnuplotrb\nMath_Sin_Data\nNewNotebook.ipynb\noctokit.rb\npoints.data\nRuby_Stuff_1.ipynb\nRuby_Stuff_2_PLOT.ipynb\nRuby_Stuff_3_more_Plot.ipynb\nRuby_Stuff_4_Gnuplot.ipynb\nRuby_Stuff_5_GnuplotRB.ipynb\nRuby_Stuff_6_Daru-n-More.ipynb\nSome_Python.ipynb\nsvg20170810-11081-1xwdkbw-0\nsvg20170810-11081-3ngc9r-0\nsvg20170810-5873-15c2pam-0\nsvg20170810-7992-he6aj-0\n"

# %%
require 'gnuplotrb'
include GnuplotRB

graph = Plot.new(['Math_Sin_Data', title: 'Sin Generated Data', with: 'lines'])
# Out:
# #<GnuplotRB::Plot:0x00000003a40530 @options=Hamster::Hash[], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003a40490 @type=:datafile, @data="'Math_Sin_Data'", @options=Hamster::Hash[:with => "lines", :title => "Sin Generated Data"]>], @cmd="plot ">

# %%
x = (1..600).map { |i| i/100.0 }
y = x.map { |xx| Math.sin(xx ** 2.3) * Math.exp(-xx) }
nil

# %%
File.open('Math_Sin_Data', 'a') { |f| (301..600).each { |i| f.puts "#{x[i]} #{y[i]}" } }

graph
# Out:
# #<GnuplotRB::Plot:0x00000003a40530 @options=Hamster::Hash[], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003a40490 @type=:datafile, @data="'Math_Sin_Data'", @options=Hamster::Hash[:with => "lines", :title => "Sin Generated Data"]>], @cmd="plot ">

# %%
x0 = x[0..200]
y0 = y[0..200]
updatable_plot = Plot.new([[x0,y0], with: 'lines', title: 'Before update'])
# Out:
# #<GnuplotRB::Plot:0x00000003720b98 @options=Hamster::Hash[], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003720ad0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000037209b8 @stored_in_file=false, @data="0.01 2.4868927436513322e-05\n0.02 0.00012125037746537788\n0.03 0.0003050352603595612\n0.04 0.0005852833558395339\n0.05 0.0009680910629643855\n0.06 0.0014577734407681439\n0.07 0.0020574274310873933\n0.08 0.0027692537987392004\n0.09 0.003594762052759224\n0.1 0.004534910638922391\n0.11 0.005590207959218235\n0.12 0.006760788066098809\n0.13 0.00804646913017274\n0.14 0.009446799705774049\n0.15 0.01096109606223854\n0.16 0.012588472790109972\n0.17 0.014327868224951947\n0.18 0.016178065796051987\n0.19 0.018137712113872287\n0.2 0.020205332406939107\n0.21 0.022379343774856307\n0.22 0.024658066619922932\n0.23 0.027039734543037177\n0.24 0.029522502932038647\n0.25 0.032104456426907436\n0.26 0.034783615412550345\n0.27
\n1.3 0.2635395692352642\n1.31 0.25854510391784696\n1.32 0.25332594439160255\n1.33 0.24788472867940875\n1.34 0.24222450873244308\n1.35 0.23634875999247731\n1.36 0.23026139037262672\n1.37 0.22396674859833074\n1.38 0.2174696318490139\n1.39 0.21077529263969366\n1.4 0.20388944488077146\n1.41 0.19681826905338567\n1.42 0.18956841643703107\n1.43 0.18214701232568642\n1.44 0.17456165816843683\n1.45 0.16682043257057236\n1.46 0.1589318910913827\n1.47 0. ...

# %%
Data stored in temporary file and its name is piped to gnuplot

# %%
x0 = x[0..400]
y0 = y[0..400]
updatable_file_plot = Plot.new([[x0,y0], with: 'lines', title: 'Before update', file: true])
# Out:
# #<GnuplotRB::Plot:0x00000003488430 @options=Hamster::Hash[], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003488390 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000034882c8 @stored_in_file=true, @file_name="tmp_data20170810-11081-2hp8vy-0">, @options=Hamster::Hash[:with => "lines", :title => "Before update"]>], @cmd="plot ">

# %%
x1 = x[401..600]
y1 = y[401..600]
updatable_file_plot.update_dataset(data: [x1,y1], title: 'After update')
# Out:
# #<GnuplotRB::Plot:0x000000032cd4d8 @options=Hamster::Hash[], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x000000032cd910 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000034882c8 @stored_in_file=true, @file_name="tmp_data20170810-11081-2hp8vy-0">, @options=Hamster::Hash[:with => "lines", :title => "After update"]>], @cmd="plot ">

# %%
updatable_file_plot
# Out:
# #<GnuplotRB::Plot:0x00000003488430 @options=Hamster::Hash[], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003488390 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000034882c8 @stored_in_file=true, @file_name="tmp_data20170810-11081-2hp8vy-0">, @options=Hamster::Hash[:with => "lines", :title => "Before update"]>], @cmd="plot ">

# %%
plot = Plot.new('sin(x)', title: 'Old title')
# Out:
# #<GnuplotRB::Plot:0x0000000318f580 @options=Hamster::Hash[:title => "Old title"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000318f378 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @cmd="plot ">

# %%
plot.title = 'New title'
# plot is container of datasets, so plot[0] is Dataset object
plot[0].title = 'Dataset title'
plot.xrange!(-1..1)
plot.yrange = 0..1
plot
# Out:
# #<GnuplotRB::Plot:0x0000000318f580 @options=Hamster::Hash[:xrange => [-1..1], :title => ["New title"], :yrange => [0..1]], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000318f378 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[:title => ["Dataset title"]]>], @cmd="plot ">

# %%
plot = Plot.new('sin(x)', 'cos(x)', 'exp(x)', xrange: 0..2)
# Out:
# #<GnuplotRB::Plot:0x000000030920b0 @options=Hamster::Hash[:xrange => 0..2], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003091e30 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x00000003091b60 @type=:math_function, @data="cos(x)", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x000000030918b8 @type=:math_function, @data="exp(x)", @options=Hamster::Hash[]>], @cmd="plot ">

# %%
plot.replace_dataset(1, 'x*x') # DOES NOT modify original plot
# Out:
# #<GnuplotRB::Plot:0x0000000301d0a8 @options=Hamster::Hash[:xrange => 0..2], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003091e30 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x0000000301d3c8 @type=:math_function, @data="x*x", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x000000030918b8 @type=:math_function, @data="exp(x)", @options=Hamster::Hash[]>], @cmd="plot ">

# %%
plot.replace_dataset!(2, 'x*x') # MODIFYES original plot
# Out:
# #<GnuplotRB::Plot:0x000000030920b0 @options=Hamster::Hash[:xrange => 0..2], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003091e30 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x00000003091b60 @type=:math_function, @data="cos(x)", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x00000002f995a0 @type=:math_function, @data="x*x", @options=Hamster::Hash[]>], @cmd="plot ">

# %%
plot.update_dataset!(0, title: '1-st dataset')
# Out:
# #<GnuplotRB::Plot:0x000000030920b0 @options=Hamster::Hash[:xrange => 0..2], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003091e30 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[:title => "1-st dataset"]>, #<GnuplotRB::Dataset:0x00000003091b60 @type=:math_function, @data="cos(x)", @options=Hamster::Hash[]>, #<GnuplotRB::Dataset:0x00000002f995a0 @type=:math_function, @data="x*x", @options=Hamster::Hash[]>], @cmd="plot ">

# %%
plot.remove_dataset!(2)
# Out:
# #<GnuplotRB::Plot:0x000000030920b0 @options=Hamster::Hash[:xrange => 0..2], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003091e30 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[:title => "1-st dataset"]>, #<GnuplotRB::Dataset:0x00000003091b60 @type=:math_function, @data="cos(x)", @options=Hamster::Hash[]>], @cmd="plot ">

# %%
require 'tk'
require 'tkextlib/tile'
 
root = TkRoot.new title: "Quick Sketch"
 
f1,f2,f3 = 3.times.map{ TkFrame.new.pack fill: :x }
 
colors = ["red","orange","yellow","lawn green","green","cyan","blue","purple","white","gray","black"]
cvariable = TkVariable.new( colors[0] )
 
# Pick colors
colors.each do |c|
  TkRadioButton.new(f2){
    text "■"
    variable cvariable
    value c
    indicatoron 0
    fg c
    activeforeground c
    pack side: :left
  }
end
 
# overlay -single
bvariable = TkVariable.new(1)
checkbutton = TkCheckButton.new(f2) {
  text "Single"
  select
  variable bvariable
  onvalue 1
  offvalue 0
  pack side: :left
}
 
# Scale
scale = Tk::Tile::Scale.new(f2){
  orient :horizontal
  from 2;  to 20;  set 10
  pack(side: :right)
}
 
# Class name
class MyNotebook < Tk::Tile::Notebook
 
  def initialize(args)
    super args
    @counter = 0
    add_canvas
  end
 
  def set_widgets(cv, scale, bv)
    @scale = scale
    @cv = cv
    @bv = bv
  end
 
  def add_canvas
    f = Tk::Tile::Frame.new(self)
    canvas = TkCanvas.new(f){
      width 400
      height 400
      bg :white
      pack
    }
    canvas.bind "B1-Motion", proc { |x, y|
      size = @scale.get
      color = @cv.value
      border = @bv.value
      TkcOval.new(canvas, x-size, y-size, x+size, y+size){
        fill color 
        width border
        # bind "B3-Motion", proc{self.destroy} 
        bind "Shift-Enter", proc{self.destroy}
      }
    }, "%x %y"
    self.add f, text: "%02d"%@counter
    @counter += 1
  end
 
  def remove_canvas
    puts self.forget :current
  end
 
end
 
notebook = MyNotebook.new(f3).pack
notebook.set_widgets cvariable, scale, bvariable
 
# Control Key 
root.bind "Control-Key-t" do
  notebook.add_canvas 
end
 
# Control key Delete
root.bind "Control-Key-Delete" do
  notebook.remove_canvas
end
 
Tk.mainloop
# Out:
# RuntimeError: can't invoke "wm" command: application has been destroyed
# /usr/lib/ruby/2.3.0/tk.rb:3013:in `_invoke'
# /usr/lib/ruby/2.3.0/tk.rb:3013:in `_invoke'
# /usr/lib/ruby/2.3.0/tk.rb:2056:in `_ip_invoke_core'
# /usr/lib/ruby/2.3.0/tk.rb:2090:in `_tk_call_core'
# /usr/lib/ruby/2.3.0/tk.rb:2114:in `tk_call'
# /usr/lib/ruby/2.3.0/tk/wm.rb:506:in `title'
# /usr/lib/ruby/2.3.0/tk/wm.rb:513:in `title'
# /usr/lib/ruby/2.3.0/tk/root.rb:31:in `block (2 levels) in new'
# /usr/lib/ruby/2.3.0/tk/root.rb:29:in `each'
# /usr/lib/ruby/2.3.0/tk/root.rb:29:in `block in new'
# /usr/lib/ruby/2.3.0/tk/root.rb:28:in `instance_eval'
# /usr/lib/ruby/2.3.0/tk/root.rb:28:in `new'
# (pry):400:in `<main>'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `eval'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:323:in `handle_line'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:243:in `block (2 levels) in eval'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `catch'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `block in eval'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `catch'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `eval'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/backend.rb:66:in `eval'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/backend.rb:12:in `eval'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/kernel.rb:87:in `execute_request'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/kernel.rb:47:in `dispatch'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/kernel.rb:37:in `run'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/command.rb:70:in `run_kernel'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/command.rb:34:in `run'
# /var/lib/gems/2.3.0/gems/iruby-0.3/bin/iruby:5:in `<top (required)>'
# /usr/local/bin/iruby:23:in `load'
# /usr/local/bin/iruby:23:in `<main>'

# %%
reset() -f
# Out:
# NoMethodError: undefined method `reset' for main:Object
# (pry):497:in `<main>'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `eval'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:323:in `handle_line'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:243:in `block (2 levels) in eval'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `catch'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:242:in `block in eval'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `catch'
# /var/lib/gems/2.3.0/gems/pry-0.10.4/lib/pry/pry_instance.rb:241:in `eval'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/backend.rb:66:in `eval'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/backend.rb:12:in `eval'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/kernel.rb:87:in `execute_request'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/kernel.rb:47:in `dispatch'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/kernel.rb:37:in `run'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/command.rb:70:in `run_kernel'
# /var/lib/gems/2.3.0/gems/iruby-0.3/lib/iruby/command.rb:34:in `run'
# /var/lib/gems/2.3.0/gems/iruby-0.3/bin/iruby:5:in `<top (required)>'
# /usr/local/bin/iruby:23:in `load'
# /usr/local/bin/iruby:23:in `<main>'
